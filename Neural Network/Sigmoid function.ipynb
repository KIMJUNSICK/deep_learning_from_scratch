# %%
# %matplotlib inline

import numpy as np
import matplotlib.pylab as plt

def sigmoid(x):
    return 1/(1+np.exp(-x))

#broadcast
x=np.array([1, -1, 3])
sigmoid(x)

x2=np.arange(-5, 5, 0.1)
y=sigmoid(x2)
plt.plot(x2, y)
plt.ylim(-0.1, 1.1)
plt.show()
